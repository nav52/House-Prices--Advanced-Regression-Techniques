# %% [markdown]
# ## Modeling to get the predictions

# %%
import pandas as pd
import numpy as np

from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.model_selection import train_test_split, RandomizedSearchCV

from xgboost import XGBRegressor

pd.pandas.set_option('display.max_columns', None)

# %%
train_data = pd.read_csv('X_train_selected.csv')

# %%
y = train_data.SalePrice
x = train_data.drop('SalePrice', axis=1)

# %%
# train test split
x_train, x_valid, y_train, y_valid = train_test_split(x,y, train_size=0.8, test_size=0.2, random_state=1)

# %%
# Hyperparameter optimization
n_estimators = [100, 500, 900, 1100, 1500,2000,5000,10000]
max_depth = [2, 3, 5, 7,8,10, 15]
booster=['gbtree','gblinear']
learning_rate=[0.01,0.05,0.1,0.15,0.20,0.25]
min_child_weight=[1,2,3,4,5]
base_score=[0.2,0.4,0.6,0.8,1]

# Define the grid of hyperparameters to search
hyperparameter_grid = {
    'n_estimators': n_estimators,
    'max_depth':max_depth,
    'learning_rate':learning_rate,
    'min_child_weight':min_child_weight,
    'booster':booster,
    'base_score':base_score
    }

#Initialise the xGBRegressor
regressor = XGBRegressor()

# %%
# Random Search CV initialiser
random_cv = RandomizedSearchCV(estimator =  regressor,
                                param_distributions = hyperparameter_grid,
                                cv = 5, 
                                n_iter = 50,
                                scoring = 'neg_mean_absolute_error',
                                n_jobs = 5,
                                verbose = 5, 
                                return_train_score = True,
                                random_state = 52)

# %%
random_cv.fit(x_train, y_train)
# Out:
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# C:\Users\navee\.conda\envs\minimal_ds\lib\site-packages\xgboost\data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# RandomizedSearchCV(cv=5,
#                    estimator=XGBRegressor(base_score=None, booster=None,
#                                           colsample_bylevel=None,
#                                           colsample_bynode=None,
#                                           colsample_bytree=None,
#                                           enable_categorical=False, gamma=None,
#                                           gpu_id=None, importance_type=None,
#                                           interaction_constraints=None,
#                                           learning_rate=None,
#                                           max_delta_step=None, max_depth=None,
#                                           min_child_weight=None, missing=nan,
#                                           monotone_constraints=...
#                    n_iter=50, n_jobs=5,
#                    param_distributions={'base_score': [0.2, 0.4, 0.6, 0.8, 1],
#                                         'booster': ['gbtree', 'gblinear'],
#                                         'learning_rate': [0.01, 0.05, 0.1, 0.15,
#                                                           0.2, 0.25],
#                                         'max_depth': [2, 3, 5, 7, 8, 10, 15],
#                                         'min_child_weight': [1, 2, 3, 4, 5],
#                                         'n_estimators': [100, 500, 900, 1100,
#                                                          1500, 2000, 5000,
#                                                          10000]},
#                    random_state=52, return_train_score=True,
#                    scoring='neg_mean_absolute_error', verbose=5)

# %%
# Get the best estimation
random_cv.best_estimator_
# Out:
# XGBRegressor(base_score=0.6, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, enable_categorical=False,
#              gamma=0, gpu_id=-1, importance_type=None,
#              interaction_constraints='', learning_rate=0.05, max_delta_step=0,
#              max_depth=2, min_child_weight=3, missing=nan,
#              monotone_constraints='()', n_estimators=500, n_jobs=12,
#              num_parallel_tree=1, predictor='auto', random_state=0, reg_alpha=0,
#              reg_lambda=1, scale_pos_weight=1, subsample=1, tree_method='exact',
#              validate_parameters=1, verbosity=None)

# %%
# Let's update the regressor with best estimated values

regressor = XGBRegressor(learning_rate=0.01,max_depth=5,n_estimators=2500,n_jobs=10)

# %%
# Let's fit the model
regressor.fit(x_train, y_train,
                early_stopping_rounds=34,
                eval_set=[(x_valid, y_valid)])
# Out:
# [0]	validation_0-rmse:11.37803
# [1]	validation_0-rmse:11.26402
# [2]	validation_0-rmse:11.15115
# [3]	validation_0-rmse:11.03941
# [4]	validation_0-rmse:10.92879
# [5]	validation_0-rmse:10.81928
# [6]	validation_0-rmse:10.71086
# [7]	validation_0-rmse:10.60353
# [8]	validation_0-rmse:10.49727
# [9]	validation_0-rmse:10.39207
# [10]	validation_0-rmse:10.28793
# [11]	validation_0-rmse:10.18483
# [12]	validation_0-rmse:10.08276
# [13]	validation_0-rmse:9.98171
# [14]	validation_0-rmse:9.88167
# [15]	validation_0-rmse:9.78264
# [16]	validation_0-rmse:9.68459
# [17]	validation_0-rmse:9.58753
# [18]	validation_0-rmse:9.49144
# [19]	validation_0-rmse:9.39631
# [20]	validation_0-rmse:9.30213
# [21]	validation_0-rmse:9.20890
# [22]	validation_0-rmse:9.11660
# [23]	validation_0-rmse:9.02523
# [24]	validation_0-rmse:8.93476
# [25]	validation_0-rmse:8.84521
# [26]	validation_0-rmse:8.75681
# [27]	validation_0-rmse:8.66929
# [28]	validation_0-rmse:8.58265
# [29]	validation_0-rmse:8.49688
# [30]	validation_0-rmse:8.41196
# [31]	validation_0-rmse:8.32789
# [32]	validation_0-rmse:8.24467
# [33]	validation_0-rmse:8.16227
# [34]	validation_0-rmse:8.08070
# [35]	validation_0-rmse:7.99994
# [36]	validation_0-rmse:7.91999
# [37]	validation_0-rmse:7.84084
# [38]	validation_0-rmse:7.76248
# [39]	validation_0-rmse:7.68491
# [40]	validation_0-rmse:7.60811
# [41]	validation_0-rmse:7.53208
# [42]	validation_0-rmse:7.45666
# [43]	validation_0-rmse:7.38214
# [44]	validation_0-rmse:7.30823
# [45]	validation_0-rmse:7.23520
# [46]	validation_0-rmse:7.16275
# [47]	validation_0-rmse:7.09117
# [48]	validation_0-rmse:7.02017
# [49]	validation_0-rmse:6.95001
# [50]	validation_0-rmse:6.88043
# [51]	validation_0-rmse:6.81167
# [52]	validation_0-rmse:6.74360
# [53]	validation_0-rmse:6.67607
# [54]	validation_0-rmse:6.60936
# [55]	validation_0-rmse:6.54318
# [56]	validation_0-rmse:6.47779
# [57]	validation_0-rmse:6.41293
# [58]	validation_0-rmse:6.34904
# [59]	validation_0-rmse:6.28550
# [60]	validation_0-rmse:6.22269
# [61]	validation_0-rmse:6.16042
# [62]	validation_0-rmse:6.09886
# [63]	validation_0-rmse:6.03811
# [64]	validation_0-rmse:5.97770
# [65]	validation_0-rmse:5.91797
# [66]	validation_0-rmse:5.85902
# [67]	validation_0-rmse:5.80037
# [68]	validation_0-rmse:5.74240
# [69]	validation_0-rmse:5.68515
# [70]	validation_0-rmse:5.62828
# [71]	validation_0-rmse:5.57205
# [72]	validation_0-rmse:5.51637
# [73]	validation_0-rmse:5.46119
# [74]	validation_0-rmse:5.40675
# [75]	validation_0-rmse:5.35292
# [76]	validation_0-rmse:5.29944
# [77]	validation_0-rmse:5.24643
# [78]	validation_0-rmse:5.19414
# [79]	validation_0-rmse:5.14243
# [80]	validation_0-rmse:5.09101
# [81]	validation_0-rmse:5.04015
# [82]	validation_0-rmse:4.98970
# [83]	validation_0-rmse:4.93999
# [84]	validation_0-rmse:4.89055
# [85]	validation_0-rmse:4.84159
# [86]	validation_0-rmse:4.79334
# [87]	validation_0-rmse:4.74547
# [88]	validation_0-rmse:4.69797
# [89]	validation_0-rmse:4.65117
# [90]	validation_0-rmse:4.60467
# [91]	validation_0-rmse:4.55886
# [92]	validation_0-rmse:4.51323
# [93]	validation_0-rmse:4.46811
# [94]	validation_0-rmse:4.42362
# [95]	validation_0-rmse:4.37935
# [96]	validation_0-rmse:4.33563
# [97]	validation_0-rmse:4.29244
# [98]	validation_0-rmse:4.24954
# [99]	validation_0-rmse:4.20702
# [100]	validation_0-rmse:4.16514
# [101]	validation_0-rmse:4.12373
# [102]	validation_0-rmse:4.08247
# [103]	validation_0-rmse:4.04173
# [104]	validation_0-rmse:4.00131
# [105]	validation_0-rmse:3.96147
# [106]	validation_0-rmse:3.92189
# [107]	validation_0-rmse:3.88287
# [108]	validation_0-rmse:3.84408
# [109]	validation_0-rmse:3.80568
# [110]	validation_0-rmse:3.76771
# [111]	validation_0-rmse:3.73023
# [112]	validation_0-rmse:3.69297
# [113]	validation_0-rmse:3.65613
# [114]	validation_0-rmse:3.61974
# [115]	validation_0-rmse:3.58364
# [116]	validation_0-rmse:3.54803
# [117]	validation_0-rmse:3.51257
# [118]	validation_0-rmse:3.47765
# [119]	validation_0-rmse:3.44293
# [120]	validation_0-rmse:3.40859
# [121]	validation_0-rmse:3.37473
# [122]	validation_0-rmse:3.34113
# [123]	validation_0-rmse:3.30779
# [124]	validation_0-rmse:3.27478
# [125]	validation_0-rmse:3.24226
# [126]	validation_0-rmse:3.21006
# [127]	validation_0-rmse:3.17804
# [128]	validation_0-rmse:3.14642
# [129]	validation_0-rmse:3.11502
# [130]	validation_0-rmse:3.08398
# [131]	validation_0-rmse:3.05343
# [132]	validation_0-rmse:3.02301
# [133]	validation_0-rmse:2.99287
# [134]	validation_0-rmse:2.96318
# [135]	validation_0-rmse:2.93374
# [136]	validation_0-rmse:2.90448
# [137]	validation_0-rmse:2.87558
# [138]	validation_0-rmse:2.84702
# [139]	validation_0-rmse:2.81852
# [140]	validation_0-rmse:2.79045
# [141]	validation_0-rmse:2.76262
# [142]	validation_0-rmse:2.73523
# [143]	validation_0-rmse:2.70807
# [144]	validation_0-rmse:2.68101
# [145]	validation_0-rmse:2.65418
# [146]	validation_0-rmse:2.62779
# [147]	validation_0-rmse:2.60171
# [148]	validation_0-rmse:2.57589
# [149]	validation_0-rmse:2.55036
# [150]	validation_0-rmse:2.52490
# [151]	validation_0-rmse:2.49984
# [152]	validation_0-rmse:2.47502
# [153]	validation_0-rmse:2.45048
# [154]	validation_0-rmse:2.42597
# [155]	validation_0-rmse:2.40185
# [156]	validation_0-rmse:2.37791
# [157]	validation_0-rmse:2.35429
# [158]	validation_0-rmse:2.33094
# [159]	validation_0-rmse:2.30783
# [160]	validation_0-rmse:2.28494
# [161]	validation_0-rmse:2.26231
# [162]	validation_0-rmse:2.23982
# [163]	validation_0-rmse:2.21748
# [164]	validation_0-rmse:2.19551
# [165]	validation_0-rmse:2.17370
# [166]	validation_0-rmse:2.15220
# [167]	validation_0-rmse:2.13075
# [168]	validation_0-rmse:2.10964
# [169]	validation_0-rmse:2.08879
# [170]	validation_0-rmse:2.06809
# [171]	validation_0-rmse:2.04756
# [172]	validation_0-rmse:2.02713
# [173]	validation_0-rmse:2.00703
# [174]	validation_0-rmse:1.98716
# [175]	validation_0-rmse:1.96753
# [176]	validation_0-rmse:1.94806
# [177]	validation_0-rmse:1.92878
# [178]	validation_0-rmse:1.90968
# [179]	validation_0-rmse:1.89078
# [180]	validation_0-rmse:1.87196
# [181]	validation_0-rmse:1.85339
# [182]	validation_0-rmse:1.83509
# [183]	validation_0-rmse:1.81683
# [184]	validation_0-rmse:1.79890
# [185]	validation_0-rmse:1.78109
# [186]	validation_0-rmse:1.76338
# [187]	validation_0-rmse:1.74591
# [188]	validation_0-rmse:1.72856
# [189]	validation_0-rmse:1.71151
# [190]	validation_0-rmse:1.69460
# [191]	validation_0-rmse:1.67783
# [192]	validation_0-rmse:1.66116
# [193]	validation_0-rmse:1.64471
# [194]	validation_0-rmse:1.62847
# [195]	validation_0-rmse:1.61244
# [196]	validation_0-rmse:1.59660
# [197]	validation_0-rmse:1.58087
# [198]	validation_0-rmse:1.56527
# [199]	validation_0-rmse:1.54978
# [200]	validation_0-rmse:1.53454
# [201]	validation_0-rmse:1.51936
# [202]	validation_0-rmse:1.50439
# [203]	validation_0-rmse:1.48951
# [204]	validation_0-rmse:1.47482
# [205]	validation_0-rmse:1.46026
# [206]	validation_0-rmse:1.44592
# [207]	validation_0-rmse:1.43154
# [208]	validation_0-rmse:1.41750
# [209]	validation_0-rmse:1.40351
# [210]	validation_0-rmse:1.38969
# [211]	validation_0-rmse:1.37600
# [212]	validation_0-rmse:1.36249
# [213]	validation_0-rmse:1.34908
# [214]	validation_0-rmse:1.33576
# [215]	validation_0-rmse:1.32266
# [216]	validation_0-rmse:1.30969
# [217]	validation_0-rmse:1.29679
# [218]	validation_0-rmse:1.28404
# [219]	validation_0-rmse:1.27149
# [220]	validation_0-rmse:1.25908
# [221]	validation_0-rmse:1.24676
# [222]	validation_0-rmse:1.23458
# [223]	validation_0-rmse:1.22248
# [224]	validation_0-rmse:1.21038
# [225]	validation_0-rmse:1.19845
# [226]	validation_0-rmse:1.18678
# [227]	validation_0-rmse:1.17515
# [228]	validation_0-rmse:1.16371
# [229]	validation_0-rmse:1.15239
# [230]	validation_0-rmse:1.14106
# [231]	validation_0-rmse:1.12991
# [232]	validation_0-rmse:1.11896
# [233]	validation_0-rmse:1.10810
# [234]	validation_0-rmse:1.09733
# [235]	validation_0-rmse:1.08673
# [236]	validation_0-rmse:1.07602
# [237]	validation_0-rmse:1.06566
# [238]	validation_0-rmse:1.05534
# [239]	validation_0-rmse:1.04505
# [240]	validation_0-rmse:1.03496
# [241]	validation_0-rmse:1.02497
# [242]	validation_0-rmse:1.01495
# [243]	validation_0-rmse:1.00518
# [244]	validation_0-rmse:0.99541
# [245]	validation_0-rmse:0.98581
# [246]	validation_0-rmse:0.97625
# [247]	validation_0-rmse:0.96676
# [248]	validation_0-rmse:0.95740
# [249]	validation_0-rmse:0.94823
# [250]	validation_0-rmse:0.93914
# [251]	validation_0-rmse:0.93012
# [252]	validation_0-rmse:0.92121
# [253]	validation_0-rmse:0.91237
# [254]	validation_0-rmse:0.90367
# [255]	validation_0-rmse:0.89506
# [256]	validation_0-rmse:0.88643
# [257]	validation_0-rmse:0.87795
# [258]	validation_0-rmse:0.86955
# [259]	validation_0-rmse:0.86123
# [260]	validation_0-rmse:0.85298
# [261]	validation_0-rmse:0.84485
# [262]	validation_0-rmse:0.83664
# [263]	validation_0-rmse:0.82869
# [264]	validation_0-rmse:0.82065
# [265]	validation_0-rmse:0.81286
# [266]	validation_0-rmse:0.80507
# [267]	validation_0-rmse:0.79743
# [268]	validation_0-rmse:0.78989
# [269]	validation_0-rmse:0.78226
# [270]	validation_0-rmse:0.77490
# [271]	validation_0-rmse:0.76748
# [272]	validation_0-rmse:0.76009
# [273]	validation_0-rmse:0.75292
# [274]	validation_0-rmse:0.74584
# [275]	validation_0-rmse:0.73869
# [276]	validation_0-rmse:0.73168
# [277]	validation_0-rmse:0.72474
# [278]	validation_0-rmse:0.71779
# [279]	validation_0-rmse:0.71099
# [280]	validation_0-rmse:0.70432
# [281]	validation_0-rmse:0.69768
# [282]	validation_0-rmse:0.69105
# [283]	validation_0-rmse:0.68451
# [284]	validation_0-rmse:0.67806
# [285]	validation_0-rmse:0.67163
# [286]	validation_0-rmse:0.66529
# [287]	validation_0-rmse:0.65904
# [288]	validation_0-rmse:0.65285
# [289]	validation_0-rmse:0.64671
# [290]	validation_0-rmse:0.64067
# [291]	validation_0-rmse:0.63476
# [292]	validation_0-rmse:0.62881
# [293]	validation_0-rmse:0.62294
# [294]	validation_0-rmse:0.61715
# [295]	validation_0-rmse:0.61139
# [296]	validation_0-rmse:0.60569
# [297]	validation_0-rmse:0.60004
# [298]	validation_0-rmse:0.59445
# [299]	validation_0-rmse:0.58892
# [300]	validation_0-rmse:0.58344
# [301]	validation_0-rmse:0.57802
# [302]	validation_0-rmse:0.57267
# [303]	validation_0-rmse:0.56736
# [304]	validation_0-rmse:0.56214
# [305]	validation_0-rmse:0.55695
# [306]	validation_0-rmse:0.55183
# [307]	validation_0-rmse:0.54681
# [308]	validation_0-rmse:0.54181
# [309]	validation_0-rmse:0.53685
# [310]	validation_0-rmse:0.53201
# [311]	validation_0-rmse:0.52714
# [312]	validation_0-rmse:0.52240
# [313]	validation_0-rmse:0.51761
# [314]	validation_0-rmse:0.51292
# [315]	validation_0-rmse:0.50830
# [316]	validation_0-rmse:0.50369
# [317]	validation_0-rmse:0.49915
# [318]	validation_0-rmse:0.49471
# [319]	validation_0-rmse:0.49022
# [320]	validation_0-rmse:0.48584
# [321]	validation_0-rmse:0.48151
# [322]	validation_0-rmse:0.47719
# [323]	validation_0-rmse:0.47293
# [324]	validation_0-rmse:0.46877
# [325]	validation_0-rmse:0.46455
# [326]	validation_0-rmse:0.46042
# [327]	validation_0-rmse:0.45637
# [328]	validation_0-rmse:0.45235
# [329]	validation_0-rmse:0.44841
# [330]	validation_0-rmse:0.44445
# [331]	validation_0-rmse:0.44057
# [332]	validation_0-rmse:0.43673
# [333]	validation_0-rmse:0.43296
# [334]	validation_0-rmse:0.42914
# [335]	validation_0-rmse:0.42542
# [336]	validation_0-rmse:0.42173
# [337]	validation_0-rmse:0.41808
# [338]	validation_0-rmse:0.41447
# [339]	validation_0-rmse:0.41091
# [340]	validation_0-rmse:0.40737
# [341]	validation_0-rmse:0.40386
# [342]	validation_0-rmse:0.40044
# [343]	validation_0-rmse:0.39708
# [344]	validation_0-rmse:0.39369
# [345]	validation_0-rmse:0.39038
# [346]	validation_0-rmse:0.38709
# [347]	validation_0-rmse:0.38381
# [348]	validation_0-rmse:0.38061
# [349]	validation_0-rmse:0.37741
# [350]	validation_0-rmse:0.37427
# [351]	validation_0-rmse:0.37115
# [352]	validation_0-rmse:0.36812
# [353]	validation_0-rmse:0.36508
# [354]	validation_0-rmse:0.36205
# [355]	validation_0-rmse:0.35912
# [356]	validation_0-rmse:0.35618
# [357]	validation_0-rmse:0.35325
# [358]	validation_0-rmse:0.35036
# [359]	validation_0-rmse:0.34756
# [360]	validation_0-rmse:0.34479
# [361]	validation_0-rmse:0.34202
# [362]	validation_0-rmse:0.33925
# [363]	validation_0-rmse:0.33653
# [364]	validation_0-rmse:0.33387
# [365]	validation_0-rmse:0.33119
# [366]	validation_0-rmse:0.32852
# [367]	validation_0-rmse:0.32597
# [368]	validation_0-rmse:0.32335
# [369]	validation_0-rmse:0.32085
# [370]	validation_0-rmse:0.31830
# [371]	validation_0-rmse:0.31584
# [372]	validation_0-rmse:0.31334
# [373]	validation_0-rmse:0.31095
# [374]	validation_0-rmse:0.30854
# [375]	validation_0-rmse:0.30612
# [376]	validation_0-rmse:0.30383
# [377]	validation_0-rmse:0.30155
# [378]	validation_0-rmse:0.29925
# [379]	validation_0-rmse:0.29695
# [380]	validation_0-rmse:0.29474
# [381]	validation_0-rmse:0.29252
# [382]	validation_0-rmse:0.29039
# [383]	validation_0-rmse:0.28825
# [384]	validation_0-rmse:0.28614
# [385]	validation_0-rmse:0.28402
# [386]	validation_0-rmse:0.28200
# [387]	validation_0-rmse:0.27993
# [388]	validation_0-rmse:0.27797
# [389]	validation_0-rmse:0.27593
# [390]	validation_0-rmse:0.27398
# [391]	validation_0-rmse:0.27201
# [392]	validation_0-rmse:0.27011
# [393]	validation_0-rmse:0.26822
# [394]	validation_0-rmse:0.26636
# [395]	validation_0-rmse:0.26452
# [396]	validation_0-rmse:0.26269
# [397]	validation_0-rmse:0.26087
# [398]	validation_0-rmse:0.25909
# [399]	validation_0-rmse:0.25731
# [400]	validation_0-rmse:0.25557
# [401]	validation_0-rmse:0.25384
# [402]	validation_0-rmse:0.25210
# [403]	validation_0-rmse:0.25043
# [404]	validation_0-rmse:0.24879
# [405]	validation_0-rmse:0.24716
# [406]	validation_0-rmse:0.24554
# [407]	validation_0-rmse:0.24393
# [408]	validation_0-rmse:0.24234
# [409]	validation_0-rmse:0.24079
# [410]	validation_0-rmse:0.23922
# [411]	validation_0-rmse:0.23771
# [412]	validation_0-rmse:0.23619
# [413]	validation_0-rmse:0.23474
# [414]	validation_0-rmse:0.23325
# [415]	validation_0-rmse:0.23187
# [416]	validation_0-rmse:0.23043
# [417]	validation_0-rmse:0.22902
# [418]	validation_0-rmse:0.22762
# [419]	validation_0-rmse:0.22625
# [420]	validation_0-rmse:0.22487
# [421]	validation_0-rmse:0.22353
# [422]	validation_0-rmse:0.22220
# [423]	validation_0-rmse:0.22092
# [424]	validation_0-rmse:0.21971
# [425]	validation_0-rmse:0.21842
# [426]	validation_0-rmse:0.21720
# [427]	validation_0-rmse:0.21595
# [428]	validation_0-rmse:0.21474
# [429]	validation_0-rmse:0.21358
# [430]	validation_0-rmse:0.21239
# [431]	validation_0-rmse:0.21127
# [432]	validation_0-rmse:0.21012
# [433]	validation_0-rmse:0.20899
# [434]	validation_0-rmse:0.20791
# [435]	validation_0-rmse:0.20681
# [436]	validation_0-rmse:0.20576
# [437]	validation_0-rmse:0.20472
# [438]	validation_0-rmse:0.20364
# [439]	validation_0-rmse:0.20264
# [440]	validation_0-rmse:0.20163
# [441]	validation_0-rmse:0.20065
# [442]	validation_0-rmse:0.19966
# [443]	validation_0-rmse:0.19872
# [444]	validation_0-rmse:0.19777
# [445]	validation_0-rmse:0.19683
# [446]	validation_0-rmse:0.19590
# [447]	validation_0-rmse:0.19496
# [448]	validation_0-rmse:0.19410
# [449]	validation_0-rmse:0.19320
# [450]	validation_0-rmse:0.19233
# [451]	validation_0-rmse:0.19148
# [452]	validation_0-rmse:0.19066
# [453]	validation_0-rmse:0.18982
# [454]	validation_0-rmse:0.18896
# [455]	validation_0-rmse:0.18818
# [456]	validation_0-rmse:0.18739
# [457]	validation_0-rmse:0.18660
# [458]	validation_0-rmse:0.18583
# [459]	validation_0-rmse:0.18509
# [460]	validation_0-rmse:0.18433
# [461]	validation_0-rmse:0.18359
# [462]	validation_0-rmse:0.18290
# [463]	validation_0-rmse:0.18216
# [464]	validation_0-rmse:0.18145
# [465]	validation_0-rmse:0.18079
# [466]	validation_0-rmse:0.18011
# [467]	validation_0-rmse:0.17946
# [468]	validation_0-rmse:0.17879
# [469]	validation_0-rmse:0.17813
# [470]	validation_0-rmse:0.17748
# [471]	validation_0-rmse:0.17685
# [472]	validation_0-rmse:0.17622
# [473]	validation_0-rmse:0.17563
# [474]	validation_0-rmse:0.17503
# [475]	validation_0-rmse:0.17444
# [476]	validation_0-rmse:0.17386
# [477]	validation_0-rmse:0.17330
# [478]	validation_0-rmse:0.17273
# [479]	validation_0-rmse:0.17217
# [480]	validation_0-rmse:0.17163
# [481]	validation_0-rmse:0.17108
# [482]	validation_0-rmse:0.17057
# [483]	validation_0-rmse:0.17006
# [484]	validation_0-rmse:0.16955
# [485]	validation_0-rmse:0.16906
# [486]	validation_0-rmse:0.16856
# [487]	validation_0-rmse:0.16807
# [488]	validation_0-rmse:0.16756
# [489]	validation_0-rmse:0.16710
# [490]	validation_0-rmse:0.16663
# [491]	validation_0-rmse:0.16619
# [492]	validation_0-rmse:0.16574
# [493]	validation_0-rmse:0.16528
# [494]	validation_0-rmse:0.16484
# [495]	validation_0-rmse:0.16437
# [496]	validation_0-rmse:0.16396
# [497]	validation_0-rmse:0.16350
# [498]	validation_0-rmse:0.16312
# [499]	validation_0-rmse:0.16271
# [500]	validation_0-rmse:0.16233
# [501]	validation_0-rmse:0.16191
# [502]	validation_0-rmse:0.16152
# [503]	validation_0-rmse:0.16115
# [504]	validation_0-rmse:0.16079
# [505]	validation_0-rmse:0.16038
# [506]	validation_0-rmse:0.16001
# [507]	validation_0-rmse:0.15967
# [508]	validation_0-rmse:0.15931
# [509]	validation_0-rmse:0.15896
# [510]	validation_0-rmse:0.15862
# [511]	validation_0-rmse:0.15830
# [512]	validation_0-rmse:0.15795
# [513]	validation_0-rmse:0.15764
# [514]	validation_0-rmse:0.15733
# [515]	validation_0-rmse:0.15699
# [516]	validation_0-rmse:0.15669
# [517]	validation_0-rmse:0.15637
# [518]	validation_0-rmse:0.15602
# [519]	validation_0-rmse:0.15576
# [520]	validation_0-rmse:0.15546
# [521]	validation_0-rmse:0.15518
# [522]	validation_0-rmse:0.15487
# [523]	validation_0-rmse:0.15461
# [524]	validation_0-rmse:0.15434
# [525]	validation_0-rmse:0.15410
# [526]	validation_0-rmse:0.15384
# [527]	validation_0-rmse:0.15358
# [528]	validation_0-rmse:0.15336
# [529]	validation_0-rmse:0.15315
# [530]	validation_0-rmse:0.15290
# [531]	validation_0-rmse:0.15266
# [532]	validation_0-rmse:0.15241
# [533]	validation_0-rmse:0.15219
# [534]	validation_0-rmse:0.15196
# [535]	validation_0-rmse:0.15175
# [536]	validation_0-rmse:0.15155
# [537]	validation_0-rmse:0.15132
# [538]	validation_0-rmse:0.15110
# [539]	validation_0-rmse:0.15091
# [540]	validation_0-rmse:0.15070
# [541]	validation_0-rmse:0.15049
# [542]	validation_0-rmse:0.15031
# [543]	validation_0-rmse:0.15011
# [544]	validation_0-rmse:0.14994
# [545]	validation_0-rmse:0.14979
# [546]	validation_0-rmse:0.14960
# [547]	validation_0-rmse:0.14941
# [548]	validation_0-rmse:0.14924
# [549]	validation_0-rmse:0.14907
# [550]	validation_0-rmse:0.14890
# [551]	validation_0-rmse:0.14872
# [552]	validation_0-rmse:0.14855
# [553]	validation_0-rmse:0.14839
# [554]	validation_0-rmse:0.14824
# [555]	validation_0-rmse:0.14809
# [556]	validation_0-rmse:0.14794
# [557]	validation_0-rmse:0.14776
# [558]	validation_0-rmse:0.14763
# [559]	validation_0-rmse:0.14748
# [560]	validation_0-rmse:0.14733
# [561]	validation_0-rmse:0.14720
# [562]	validation_0-rmse:0.14706
# [563]	validation_0-rmse:0.14692
# [564]	validation_0-rmse:0.14677
# [565]	validation_0-rmse:0.14663
# [566]	validation_0-rmse:0.14648
# [567]	validation_0-rmse:0.14636
# [568]	validation_0-rmse:0.14621
# [569]	validation_0-rmse:0.14607
# [570]	validation_0-rmse:0.14593
# [571]	validation_0-rmse:0.14578
# [572]	validation_0-rmse:0.14567
# [573]	validation_0-rmse:0.14556
# [574]	validation_0-rmse:0.14544
# [575]	validation_0-rmse:0.14530
# [576]	validation_0-rmse:0.14517
# [577]	validation_0-rmse:0.14507
# [578]	validation_0-rmse:0.14497
# [579]	validation_0-rmse:0.14485
# [580]	validation_0-rmse:0.14474
# [581]	validation_0-rmse:0.14462
# [582]	validation_0-rmse:0.14452
# [583]	validation_0-rmse:0.14441
# [584]	validation_0-rmse:0.14430
# [585]	validation_0-rmse:0.14418
# [586]	validation_0-rmse:0.14407
# [587]	validation_0-rmse:0.14400
# [588]	validation_0-rmse:0.14392
# [589]	validation_0-rmse:0.14384
# [590]	validation_0-rmse:0.14375
# [591]	validation_0-rmse:0.14366
# [592]	validation_0-rmse:0.14358
# [593]	validation_0-rmse:0.14347
# [594]	validation_0-rmse:0.14340
# [595]	validation_0-rmse:0.14330
# [596]	validation_0-rmse:0.14322
# [597]	validation_0-rmse:0.14314
# [598]	validation_0-rmse:0.14305
# [599]	validation_0-rmse:0.14297
# [600]	validation_0-rmse:0.14288
# [601]	validation_0-rmse:0.14282
# [602]	validation_0-rmse:0.14273
# [603]	validation_0-rmse:0.14269
# [604]	validation_0-rmse:0.14260
# [605]	validation_0-rmse:0.14252
# [606]	validation_0-rmse:0.14246
# [607]	validation_0-rmse:0.14239
# [608]	validation_0-rmse:0.14231
# [609]	validation_0-rmse:0.14224
# [610]	validation_0-rmse:0.14216
# [611]	validation_0-rmse:0.14212
# [612]	validation_0-rmse:0.14206
# [613]	validation_0-rmse:0.14199
# [614]	validation_0-rmse:0.14192
# [615]	validation_0-rmse:0.14185
# [616]	validation_0-rmse:0.14182
# [617]	validation_0-rmse:0.14175
# [618]	validation_0-rmse:0.14170
# [619]	validation_0-rmse:0.14166
# [620]	validation_0-rmse:0.14160
# [621]	validation_0-rmse:0.14157
# [622]	validation_0-rmse:0.14151
# [623]	validation_0-rmse:0.14144
# [624]	validation_0-rmse:0.14138
# [625]	validation_0-rmse:0.14131
# [626]	validation_0-rmse:0.14127
# [627]	validation_0-rmse:0.14121
# [628]	validation_0-rmse:0.14118
# [629]	validation_0-rmse:0.14112
# [630]	validation_0-rmse:0.14107
# [631]	validation_0-rmse:0.14103
# [632]	validation_0-rmse:0.14096
# [633]	validation_0-rmse:0.14091
# [634]	validation_0-rmse:0.14087
# [635]	validation_0-rmse:0.14083
# [636]	validation_0-rmse:0.14078
# [637]	validation_0-rmse:0.14073
# [638]	validation_0-rmse:0.14067
# [639]	validation_0-rmse:0.14065
# [640]	validation_0-rmse:0.14060
# [641]	validation_0-rmse:0.14056
# [642]	validation_0-rmse:0.14053
# [643]	validation_0-rmse:0.14048
# [644]	validation_0-rmse:0.14042
# [645]	validation_0-rmse:0.14040
# [646]	validation_0-rmse:0.14036
# [647]	validation_0-rmse:0.14033
# [648]	validation_0-rmse:0.14027
# [649]	validation_0-rmse:0.14027
# [650]	validation_0-rmse:0.14022
# [651]	validation_0-rmse:0.14020
# [652]	validation_0-rmse:0.14017
# [653]	validation_0-rmse:0.14011
# [654]	validation_0-rmse:0.14007
# [655]	validation_0-rmse:0.14002
# [656]	validation_0-rmse:0.13998
# [657]	validation_0-rmse:0.13993
# [658]	validation_0-rmse:0.13988
# [659]	validation_0-rmse:0.13985
# [660]	validation_0-rmse:0.13982
# [661]	validation_0-rmse:0.13979
# [662]	validation_0-rmse:0.13978
# [663]	validation_0-rmse:0.13978
# [664]	validation_0-rmse:0.13974
# [665]	validation_0-rmse:0.13970
# [666]	validation_0-rmse:0.13969
# [667]	validation_0-rmse:0.13965
# [668]	validation_0-rmse:0.13961
# [669]	validation_0-rmse:0.13957
# [670]	validation_0-rmse:0.13955
# [671]	validation_0-rmse:0.13952
# [672]	validation_0-rmse:0.13949
# [673]	validation_0-rmse:0.13947
# [674]	validation_0-rmse:0.13945
# [675]	validation_0-rmse:0.13942
# [676]	validation_0-rmse:0.13941
# [677]	validation_0-rmse:0.13937
# [678]	validation_0-rmse:0.13937
# [679]	validation_0-rmse:0.13934
# [680]	validation_0-rmse:0.13932
# [681]	validation_0-rmse:0.13930
# [682]	validation_0-rmse:0.13926
# [683]	validation_0-rmse:0.13924
# [684]	validation_0-rmse:0.13922
# [685]	validation_0-rmse:0.13920
# [686]	validation_0-rmse:0.13921
# [687]	validation_0-rmse:0.13919
# [688]	validation_0-rmse:0.13916
# [689]	validation_0-rmse:0.13915
# [690]	validation_0-rmse:0.13912
# [691]	validation_0-rmse:0.13913
# [692]	validation_0-rmse:0.13911
# [693]	validation_0-rmse:0.13908
# [694]	validation_0-rmse:0.13906
# [695]	validation_0-rmse:0.13902
# [696]	validation_0-rmse:0.13903
# [697]	validation_0-rmse:0.13901
# [698]	validation_0-rmse:0.13899
# [699]	validation_0-rmse:0.13896
# [700]	validation_0-rmse:0.13895
# [701]	validation_0-rmse:0.13892
# [702]	validation_0-rmse:0.13890
# [703]	validation_0-rmse:0.13887
# [704]	validation_0-rmse:0.13888
# [705]	validation_0-rmse:0.13886
# [706]	validation_0-rmse:0.13884
# [707]	validation_0-rmse:0.13883
# [708]	validation_0-rmse:0.13881
# [709]	validation_0-rmse:0.13879
# [710]	validation_0-rmse:0.13879
# [711]	validation_0-rmse:0.13878
# [712]	validation_0-rmse:0.13877
# [713]	validation_0-rmse:0.13874
# [714]	validation_0-rmse:0.13874
# [715]	validation_0-rmse:0.13875
# [716]	validation_0-rmse:0.13873
# [717]	validation_0-rmse:0.13873
# [718]	validation_0-rmse:0.13870
# [719]	validation_0-rmse:0.13868
# [720]	validation_0-rmse:0.13868
# [721]	validation_0-rmse:0.13868
# [722]	validation_0-rmse:0.13866
# [723]	validation_0-rmse:0.13869
# [724]	validation_0-rmse:0.13867
# [725]	validation_0-rmse:0.13867
# [726]	validation_0-rmse:0.13869
# [727]	validation_0-rmse:0.13871
# [728]	validation_0-rmse:0.13869
# [729]	validation_0-rmse:0.13869
# [730]	validation_0-rmse:0.13867
# [731]	validation_0-rmse:0.13864
# [732]	validation_0-rmse:0.13864
# [733]	validation_0-rmse:0.13863
# [734]	validation_0-rmse:0.13861
# [735]	validation_0-rmse:0.13860
# [736]	validation_0-rmse:0.13861
# [737]	validation_0-rmse:0.13859
# [738]	validation_0-rmse:0.13859
# [739]	validation_0-rmse:0.13860
# [740]	validation_0-rmse:0.13862
# [741]	validation_0-rmse:0.13862
# [742]	validation_0-rmse:0.13859
# [743]	validation_0-rmse:0.13857
# [744]	validation_0-rmse:0.13856
# [745]	validation_0-rmse:0.13857
# [746]	validation_0-rmse:0.13856
# [747]	validation_0-rmse:0.13853
# [748]	validation_0-rmse:0.13855
# [749]	validation_0-rmse:0.13855
# [750]	validation_0-rmse:0.13853
# [751]	validation_0-rmse:0.13852
# [752]	validation_0-rmse:0.13852
# [753]	validation_0-rmse:0.13850
# [754]	validation_0-rmse:0.13849
# [755]	validation_0-rmse:0.13848
# [756]	validation_0-rmse:0.13846
# [757]	validation_0-rmse:0.13842
# [758]	validation_0-rmse:0.13839
# [759]	validation_0-rmse:0.13842
# [760]	validation_0-rmse:0.13841
# [761]	validation_0-rmse:0.13840
# [762]	validation_0-rmse:0.13842
# [763]	validation_0-rmse:0.13841
# [764]	validation_0-rmse:0.13837
# [765]	validation_0-rmse:0.13836
# [766]	validation_0-rmse:0.13838
# [767]	validation_0-rmse:0.13837
# [768]	validation_0-rmse:0.13838
# [769]	validation_0-rmse:0.13838
# [770]	validation_0-rmse:0.13835
# [771]	validation_0-rmse:0.13833
# [772]	validation_0-rmse:0.13832
# [773]	validation_0-rmse:0.13832
# [774]	validation_0-rmse:0.13829
# [775]	validation_0-rmse:0.13828
# [776]	validation_0-rmse:0.13829
# [777]	validation_0-rmse:0.13825
# [778]	validation_0-rmse:0.13825
# [779]	validation_0-rmse:0.13824
# [780]	validation_0-rmse:0.13825
# [781]	validation_0-rmse:0.13822
# [782]	validation_0-rmse:0.13822
# [783]	validation_0-rmse:0.13822
# [784]	validation_0-rmse:0.13822
# [785]	validation_0-rmse:0.13820
# [786]	validation_0-rmse:0.13819
# [787]	validation_0-rmse:0.13820
# [788]	validation_0-rmse:0.13818
# [789]	validation_0-rmse:0.13816
# [790]	validation_0-rmse:0.13815
# [791]	validation_0-rmse:0.13815
# [792]	validation_0-rmse:0.13816
# [793]	validation_0-rmse:0.13814
# [794]	validation_0-rmse:0.13814
# [795]	validation_0-rmse:0.13814
# [796]	validation_0-rmse:0.13811
# [797]	validation_0-rmse:0.13811
# [798]	validation_0-rmse:0.13812
# [799]	validation_0-rmse:0.13809
# [800]	validation_0-rmse:0.13808
# [801]	validation_0-rmse:0.13808
# [802]	validation_0-rmse:0.13805
# [803]	validation_0-rmse:0.13802
# [804]	validation_0-rmse:0.13802
# [805]	validation_0-rmse:0.13803
# [806]	validation_0-rmse:0.13804
# [807]	validation_0-rmse:0.13803
# [808]	validation_0-rmse:0.13803
# [809]	validation_0-rmse:0.13801
# [810]	validation_0-rmse:0.13801
# [811]	validation_0-rmse:0.13801
# [812]	validation_0-rmse:0.13799
# [813]	validation_0-rmse:0.13797
# [814]	validation_0-rmse:0.13798
# [815]	validation_0-rmse:0.13799
# [816]	validation_0-rmse:0.13799
# [817]	validation_0-rmse:0.13797
# [818]	validation_0-rmse:0.13795
# [819]	validation_0-rmse:0.13793
# [820]	validation_0-rmse:0.13792
# [821]	validation_0-rmse:0.13792
# [822]	validation_0-rmse:0.13790
# [823]	validation_0-rmse:0.13790
# [824]	validation_0-rmse:0.13792
# [825]	validation_0-rmse:0.13789
# [826]	validation_0-rmse:0.13789
# [827]	validation_0-rmse:0.13788
# [828]	validation_0-rmse:0.13789
# [829]	validation_0-rmse:0.13787
# [830]	validation_0-rmse:0.13786
# [831]	validation_0-rmse:0.13788
# [832]	validation_0-rmse:0.13788
# [833]	validation_0-rmse:0.13786
# [834]	validation_0-rmse:0.13785
# [835]	validation_0-rmse:0.13786
# [836]	validation_0-rmse:0.13785
# [837]	validation_0-rmse:0.13784
# [838]	validation_0-rmse:0.13784
# [839]	validation_0-rmse:0.13784
# [840]	validation_0-rmse:0.13782
# [841]	validation_0-rmse:0.13782
# [842]	validation_0-rmse:0.13782
# [843]	validation_0-rmse:0.13780
# [844]	validation_0-rmse:0.13780
# [845]	validation_0-rmse:0.13780
# [846]	validation_0-rmse:0.13780
# [847]	validation_0-rmse:0.13781
# [848]	validation_0-rmse:0.13779
# [849]	validation_0-rmse:0.13779
# [850]	validation_0-rmse:0.13779
# [851]	validation_0-rmse:0.13778
# [852]	validation_0-rmse:0.13778
# [853]	validation_0-rmse:0.13778
# [854]	validation_0-rmse:0.13775
# [855]	validation_0-rmse:0.13776
# [856]	validation_0-rmse:0.13776
# [857]	validation_0-rmse:0.13775
# [858]	validation_0-rmse:0.13775
# [859]	validation_0-rmse:0.13775
# [860]	validation_0-rmse:0.13775
# [861]	validation_0-rmse:0.13774
# [862]	validation_0-rmse:0.13774
# [863]	validation_0-rmse:0.13775
# [864]	validation_0-rmse:0.13773
# [865]	validation_0-rmse:0.13773
# [866]	validation_0-rmse:0.13773
# [867]	validation_0-rmse:0.13774
# [868]	validation_0-rmse:0.13771
# [869]	validation_0-rmse:0.13772
# [870]	validation_0-rmse:0.13769
# [871]	validation_0-rmse:0.13769
# [872]	validation_0-rmse:0.13766
# [873]	validation_0-rmse:0.13766
# [874]	validation_0-rmse:0.13764
# [875]	validation_0-rmse:0.13765
# [876]	validation_0-rmse:0.13765
# [877]	validation_0-rmse:0.13764
# [878]	validation_0-rmse:0.13765
# [879]	validation_0-rmse:0.13765
# [880]	validation_0-rmse:0.13766
# [881]	validation_0-rmse:0.13765
# [882]	validation_0-rmse:0.13766
# [883]	validation_0-rmse:0.13765
# [884]	validation_0-rmse:0.13764
# [885]	validation_0-rmse:0.13764
# [886]	validation_0-rmse:0.13765
# [887]	validation_0-rmse:0.13764
# [888]	validation_0-rmse:0.13761
# [889]	validation_0-rmse:0.13761
# [890]	validation_0-rmse:0.13761
# [891]	validation_0-rmse:0.13761
# [892]	validation_0-rmse:0.13761
# [893]	validation_0-rmse:0.13758
# [894]	validation_0-rmse:0.13759
# [895]	validation_0-rmse:0.13759
# [896]	validation_0-rmse:0.13759
# [897]	validation_0-rmse:0.13760
# [898]	validation_0-rmse:0.13757
# [899]	validation_0-rmse:0.13756
# [900]	validation_0-rmse:0.13755
# [901]	validation_0-rmse:0.13752
# [902]	validation_0-rmse:0.13753
# [903]	validation_0-rmse:0.13751
# [904]	validation_0-rmse:0.13748
# [905]	validation_0-rmse:0.13747
# [906]	validation_0-rmse:0.13747
# [907]	validation_0-rmse:0.13746
# [908]	validation_0-rmse:0.13743
# [909]	validation_0-rmse:0.13744
# [910]	validation_0-rmse:0.13745
# [911]	validation_0-rmse:0.13744
# [912]	validation_0-rmse:0.13745
# [913]	validation_0-rmse:0.13745
# [914]	validation_0-rmse:0.13745
# [915]	validation_0-rmse:0.13746
# [916]	validation_0-rmse:0.13745
# [917]	validation_0-rmse:0.13744
# [918]	validation_0-rmse:0.13745
# [919]	validation_0-rmse:0.13742
# [920]	validation_0-rmse:0.13743
# [921]	validation_0-rmse:0.13742
# [922]	validation_0-rmse:0.13742
# [923]	validation_0-rmse:0.13741
# [924]	validation_0-rmse:0.13740
# [925]	validation_0-rmse:0.13738
# [926]	validation_0-rmse:0.13738
# [927]	validation_0-rmse:0.13738
# [928]	validation_0-rmse:0.13736
# [929]	validation_0-rmse:0.13736
# [930]	validation_0-rmse:0.13735
# [931]	validation_0-rmse:0.13735
# [932]	validation_0-rmse:0.13736
# [933]	validation_0-rmse:0.13735
# [934]	validation_0-rmse:0.13736
# [935]	validation_0-rmse:0.13735
# [936]	validation_0-rmse:0.13734
# [937]	validation_0-rmse:0.13733
# [938]	validation_0-rmse:0.13734
# [939]	validation_0-rmse:0.13734
# [940]	validation_0-rmse:0.13733
# [941]	validation_0-rmse:0.13732
# [942]	validation_0-rmse:0.13730
# [943]	validation_0-rmse:0.13731
# [944]	validation_0-rmse:0.13731
# [945]	validation_0-rmse:0.13732
# [946]	validation_0-rmse:0.13730
# [947]	validation_0-rmse:0.13729
# [948]	validation_0-rmse:0.13731
# [949]	validation_0-rmse:0.13730
# [950]	validation_0-rmse:0.13730
# [951]	validation_0-rmse:0.13730
# [952]	validation_0-rmse:0.13729
# [953]	validation_0-rmse:0.13728
# [954]	validation_0-rmse:0.13727
# [955]	validation_0-rmse:0.13726
# [956]	validation_0-rmse:0.13726
# [957]	validation_0-rmse:0.13727
# [958]	validation_0-rmse:0.13726
# [959]	validation_0-rmse:0.13726
# [960]	validation_0-rmse:0.13726
# [961]	validation_0-rmse:0.13723
# [962]	validation_0-rmse:0.13723
# [963]	validation_0-rmse:0.13724
# [964]	validation_0-rmse:0.13724
# [965]	validation_0-rmse:0.13723
# [966]	validation_0-rmse:0.13722
# [967]	validation_0-rmse:0.13721
# [968]	validation_0-rmse:0.13720
# [969]	validation_0-rmse:0.13719
# [970]	validation_0-rmse:0.13719
# [971]	validation_0-rmse:0.13719
# [972]	validation_0-rmse:0.13717
# [973]	validation_0-rmse:0.13718
# [974]	validation_0-rmse:0.13715
# [975]	validation_0-rmse:0.13714
# [976]	validation_0-rmse:0.13715
# [977]	validation_0-rmse:0.13714
# [978]	validation_0-rmse:0.13711
# [979]	validation_0-rmse:0.13712
# [980]	validation_0-rmse:0.13712
# [981]	validation_0-rmse:0.13711
# [982]	validation_0-rmse:0.13710
# [983]	validation_0-rmse:0.13710
# [984]	validation_0-rmse:0.13711
# [985]	validation_0-rmse:0.13713
# [986]	validation_0-rmse:0.13710
# [987]	validation_0-rmse:0.13710
# [988]	validation_0-rmse:0.13710
# [989]	validation_0-rmse:0.13711
# [990]	validation_0-rmse:0.13712
# [991]	validation_0-rmse:0.13712
# [992]	validation_0-rmse:0.13713
# [993]	validation_0-rmse:0.13712
# [994]	validation_0-rmse:0.13710
# [995]	validation_0-rmse:0.13711
# [996]	validation_0-rmse:0.13710
# [997]	validation_0-rmse:0.13712
# [998]	validation_0-rmse:0.13710
# [999]	validation_0-rmse:0.13711
# [1000]	validation_0-rmse:0.13709
# [1001]	validation_0-rmse:0.13709
# [1002]	validation_0-rmse:0.13710
# [1003]	validation_0-rmse:0.13712
# [1004]	validation_0-rmse:0.13712
# [1005]	validation_0-rmse:0.13712
# [1006]	validation_0-rmse:0.13712
# [1007]	validation_0-rmse:0.13714
# [1008]	validation_0-rmse:0.13715
# [1009]	validation_0-rmse:0.13717
# [1010]	validation_0-rmse:0.13718
# [1011]	validation_0-rmse:0.13718
# [1012]	validation_0-rmse:0.13717
# [1013]	validation_0-rmse:0.13718
# [1014]	validation_0-rmse:0.13719
# [1015]	validation_0-rmse:0.13719
# [1016]	validation_0-rmse:0.13718
# [1017]	validation_0-rmse:0.13718
# [1018]	validation_0-rmse:0.13716
# [1019]	validation_0-rmse:0.13717
# [1020]	validation_0-rmse:0.13718
# [1021]	validation_0-rmse:0.13718
# [1022]	validation_0-rmse:0.13717
# [1023]	validation_0-rmse:0.13718
# [1024]	validation_0-rmse:0.13718
# [1025]	validation_0-rmse:0.13717
# [1026]	validation_0-rmse:0.13718
# [1027]	validation_0-rmse:0.13718
# [1028]	validation_0-rmse:0.13717
# [1029]	validation_0-rmse:0.13715
# [1030]	validation_0-rmse:0.13715
# [1031]	validation_0-rmse:0.13715
# [1032]	validation_0-rmse:0.13716
# [1033]	validation_0-rmse:0.13716
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, enable_categorical=False,
#              gamma=0, gpu_id=-1, importance_type=None,
#              interaction_constraints='', learning_rate=0.01, max_delta_step=0,
#              max_depth=5, min_child_weight=1, missing=nan,
#              monotone_constraints='()', n_estimators=2500, n_jobs=10,
#              num_parallel_tree=1, predictor='auto', random_state=0, reg_alpha=0,
#              reg_lambda=1, scale_pos_weight=1, subsample=1, tree_method='exact',
#              validate_parameters=1, verbosity=None)

# %%
# Verifying with the validation data and getting the predictions, mean absolute error and root mean squared log error 
predictions = regressor.predict(x_valid)
mae = mean_absolute_error(y_valid, predictions)
print('MAE: {}'.format(mae))

rmsle = np.sqrt(mean_squared_error(np.log(y_valid), np.log(predictions)))
print('RMSLE: {}'.format(rmsle))
# Out:
# MAE: 0.09382401548148712
# RMSLE: 0.011636075990609583

# %%
# Let's get the test data and predict with our model.
# Then we'll save the it as submissions.csv and submit in the Kaggle

OG_X_test = pd.read_csv('X_test.csv')
x_test = pd.read_csv('X_test_selected.csv')
submit_predictions = regressor.predict(x_test)
scaled_predictions = np.exp(submit_predictions)             # scaling out of log distribution
# Save test predictions to file
output = pd.DataFrame({'Id': OG_X_test.Id,
                       'SalePrice': scaled_predictions})
output.to_csv('submission.csv', index=False)
